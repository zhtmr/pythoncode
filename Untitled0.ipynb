# %% [markdown]
# <a href="https://colab.research.google.com/github/zhtmr/pythoncode/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 블로그 검색

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "sS88hc82YxTmL1h6UTOg"
client_secret = "WEBJod3FTg"


query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'date'

web_df = pd.DataFrame(columns=("Title", "Link", "Description", "Postdate"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort
    
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            postdate = items[item_index]['postdate']
            web_df.loc[idx] = [title, link, description, postdate]
            idx += 1
    else:
        print("Error Code:" + rescode)

web_df# web_df.to_csv('C:\Users\c\pythoncode\web_df.csv', sep=',')  csv로
# Out:
# 검색 질의: 만두
#                                        Title  ...  Postdate
# 0                                       단풍놀이  ...  20201119
# 1    동탄 코다리냉면을 아주 맛나게 잘하는 &lt;생태명가 코다리냉면&gt;  ...  20201119
# 2                                     (국수전문)  ...  20201119
# 3                        맛있는 냉동만두추천 해화당 굴림만두  ...  20201119
# 4          안동 퀵 가구버리기 부모님 자연인 살던집 시골집 빈집...   ...  20201119
# ..                                       ...  ...       ...
# 995                       BEST X.O.만두에 투표하라!  ...  20201118
# 996                         2020.11.19메뉴입니다.  ...  20201118
# 997                             일상글을 나도 써보자!  ...  20201118
# 998                   2020년 11월 18일 홍콩에서 한 일  ...  20201118
# 999              일상블로그: 끝나지 않은 공모전과 예지를 만나다!  ...  20201118
#
# [1000 rows x 4 columns]

# %% [markdown]
# 지식인 검색

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "sS88hc82YxTmL1h6UTOg"
client_secret = "WEBJod3FTg"


query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort
    
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1
    else:
        print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의: 만두
#                             Title  ...                                        Description
# 0                    맛있는 냉동 만두 추천  ...  맛있는 냉동 만두 추천해주세요 맛있는 냉동 만두로 비비고가 인기 있는거 같은데 가격...
# 1             춘절에 만두는 먹는 이유가 뭔가요?  ...  어떠한 한어 병음과 관련되어 있어서 만두를 먹는거라고 하는데 그게 뭔지 자세하게 알...
# 2          고향만두 먹다가 이물질이 나왔어요....  ...  고향만두에서 사진에서 처럼 손가락 마디만한 플러스틱 실이 나왔어요...... 만두를...
# 3            납작만두상품중 어떤 상품이 괜찮나요?  ...  썸타는 사람 깜짝선물을줄 계획입니다납작만두... 내공 15 23살이 좋아할 납작만두...
# 4                      굽네 닭가슴살 만두  ...  다이어트 중이라 아침으로 거의 굽네 닭가슴살 만두를 먹는데요 나트륨함량이... 하는...
# ..                            ...  ...                                                ...
# 995  탐론 17-50 f2. 애기만두 렌즈 질문입니다..  ...  ... 애기만두 를 알아 보고있습니다.. 인물촬영시 85mm이상? 그정도 되야 한다...
# 996          만두국 국간장대신 양조간장 넣어도 되  ...  만두국 국간장대신 양조간장 넣어도 되나욪? 양조간장을 넣으면 덜컨하고 달아서 맛없습...
# 997                 만두를 만든사람이 관우?  ...  만두를 만든사람이 관우?  원래 만두는 중국 남만인(南蠻人)들의 음식이라 한다. 제...
# ...

# %% [markdown]
# 쇼핑 검색

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "sS88hc82YxTmL1h6UTOg"
client_secret = "WEBJod3FTg"


query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'

web_df = pd.DataFrame(columns=("Title", "Link", "Image", "Lprice", "Hprice", "mallName", "productId", "productType", "maker", "brand", "category1", "category2", "category3", "category4"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)
    
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            lprice = items[item_index]['lprice']
            hprice = items[item_index]['hprice']
            mallName = items[item_index]['mallName']
            productId = items[item_index]['productId']
            productType = items[item_index]['productType']
            maker = items[item_index]['maker']
            brand = items[item_index]['brand']
            category1 = items[item_index]['category1']
            category2 = items[item_index]['category2']
            category3 = items[item_index]['category3']
            category4 = items[item_index]['category4']
            web_df.loc[idx] = [title, link, image, lprice, hprice, mallName, productId, productType, maker, brand, category1, category2, category3, category4 ]
            idx += 1
    else:
        print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의: 만두
#                                   Title  ... category4
# 0                            구리야끼만두 2kg  ...
# 1     [CJ직배송] 비비고 왕교자 1.05kg 3봉 만두 골라담기  ...
# 2         사조오양 렌지 포자 만두 180g 고기 김치 브로콜리  ...
# 3                   한만두 아삭한 김치왕만두 1.4kg  ...
# 4    사조오양 포자만두/ 고기 육즙가득 김치 갈비 한입 매운 찐만두  ...
# ..                                  ...  ...       ...
# 995                        청정원 민속만두 1kg  ...
# 996       굿프랜즈 갈비만두 1kg 1봉 간단한저녁메뉴 맥주안주  ...
# 997  아하식품 고기없이 담백한 두부손만두 매콤한 김치손만두 총 2팩  ...
# 998    신세계푸드 올반키친 명란군만두 벚꽃에디션 1.05kg 2팩  ...
# 999                    (엄지)튀김군만두 1,400g  ...
#
# [1000 rows x 14 columns]
